# %% [markdown]
# <a href="https://colab.research.google.com/github/dangkhoa152/3122410187_TranLeDangKhoa_DataAnalysis/blob/main/Chapter6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # CHAPTER 6

# %% [markdown]
# ## Reading and Writing Data in Text Format

# %%
import pandas as pd

# Tạo DataFrame giả
df = pd.DataFrame({
    "a": [1, 2, 3, 4],
    "b": ["foo", "bar", "baz", "qux"],
    "c": [True, False, True, False]
})

# Lưu thành CSV trong thư mục examples/
import os
os.makedirs("examples", exist_ok=True)
df.to_csv("examples/ex1.csv", index=False)

# Đọc lại để kiểm tra
data = pd.read_csv("examples/ex1.csv")
print(data)
# Out:
#    a    b      c
# 0  1  foo   True
# 1  2  bar  False
# 2  3  baz   True
# 3  4  qux  False

# %%
df = pd.read_csv("examples/ex1.csv")
df
# Out:
#    a    b      c
# 0  1  foo   True
# 1  2  bar  False
# 2  3  baz   True
# 3  4  qux  False

# %%
import pandas as pd
import os

# Đảm bảo thư mục examples tồn tại
os.makedirs("examples", exist_ok=True)

# Tạo DataFrame giả để lưu thành ex2.csv
df2 = pd.DataFrame({
    "col1": range(1, 6),
    "col2": ["alpha", "beta", "gamma", "delta", "epsilon"],
    "col3": [10.5, 20.1, 30.2, 40.7, 50.3]
})

# Lưu ra file
df2.to_csv("examples/ex2.csv", index=False)

# Đọc lại để kiểm tra
print(pd.read_csv("examples/ex2.csv"))
# Out:
#    col1     col2  col3
# 0     1    alpha  10.5
# 1     2     beta  20.1
# 2     3    gamma  30.2
# 3     4    delta  40.7
# 4     5  epsilon  50.3

# %%
pd.read_csv("examples/ex2.csv", header=None)
pd.read_csv("examples/ex2.csv", names=["a", "b", "c", "d", "message"])
# Out:
#       a        b     c   d  message
# 0  col1     col2  col3 NaN      NaN
# 1     1    alpha  10.5 NaN      NaN
# 2     2     beta  20.1 NaN      NaN
# 3     3    gamma  30.2 NaN      NaN
# 4     4    delta  40.7 NaN      NaN
# 5     5  epsilon  50.3 NaN      NaN

# %%
names = ["a", "b", "c", "d", "message"]
pd.read_csv("examples/ex2.csv", names=names, index_col="message")
# Out:
#             a        b     c   d
# message
# NaN      col1     col2  col3 NaN
# NaN         1    alpha  10.5 NaN
# NaN         2     beta  20.1 NaN
# NaN         3    gamma  30.2 NaN
# NaN         4    delta  40.7 NaN
# NaN         5  epsilon  50.3 NaN

# %%
import pandas as pd
import os

# Đảm bảo thư mục examples tồn tại
os.makedirs("examples", exist_ok=True)

# Tạo DataFrame có 2 cột key để làm MultiIndex
df_mindex = pd.DataFrame({
    "key1": ["one", "one", "two", "two", "three", "three"],
    "key2": ["a", "b", "a", "b", "a", "b"],
    "value1": [1, 2, 3, 4, 5, 6],
    "value2": [10, 20, 30, 40, 50, 60]
})

# Lưu ra file CSV
df_mindex.to_csv("examples/csv_mindex.csv", index=False)

# Đọc lại với MultiIndex
parsed = pd.read_csv("examples/csv_mindex.csv", index_col=["key1", "key2"])
print(parsed)
# Out:
#             value1  value2
# key1  key2
# one   a          1      10
#       b          2      20
# two   a          3      30
#       b          4      40
# three a          5      50
#       b          6      60

# %%
import os

# Đảm bảo thư mục examples tồn tại
os.makedirs("examples", exist_ok=True)

# Tạo file ex3.txt giả
with open("examples/ex3.txt", "w") as f:
    f.write("a b c\n")
    f.write("1 foo True\n")
    f.write("2 bar False\n")
    f.write("3 baz True\n")
    f.write("4 qux False\n")

# Kiểm tra nội dung
with open("examples/ex3.txt") as f:
    print(f.read())
# Out:
# a b c
# 1 foo True
# 2 bar False
# 3 baz True
# 4 qux False

# %%
result = pd.read_csv("examples/ex3.txt", sep="\s+")
result
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\s'
# <>:1: SyntaxWarning: invalid escape sequence '\s'
# /tmp/ipython-input-1673285606.py:1: SyntaxWarning: invalid escape sequence '\s'
#   result = pd.read_csv("examples/ex3.txt", sep="\s+")
#    a    b      c
# 0  1  foo   True
# 1  2  bar  False
# 2  3  baz   True
# 3  4  qux  False

# %%
import os
import pandas as pd

# Đảm bảo thư mục examples tồn tại
os.makedirs("examples", exist_ok=True)

# Tạo nội dung giả, có vài dòng sẽ bị bỏ qua
with open("examples/ex4.csv", "w") as f:
    f.write("Header line we want to skip\n")
    f.write("a,b,c\n")
    f.write("This line will be skipped\n")
    f.write("Another line to skip\n")
    f.write("1,2,3\n")
    f.write("4,5,6\n")
    f.write("7,8,9\n")

# Xem thử nội dung file
with open("examples/ex4.csv") as f:
    print(f.read())

# Đọc lại, bỏ qua dòng 0,2,3
df_ex4 = pd.read_csv("examples/ex4.csv", skiprows=[0, 2, 3])
print("\nKết quả sau khi skip rows:")
print(df_ex4)
# Out:
# Header line we want to skip
# a,b,c
# This line will be skipped
# Another line to skip
# 1,2,3
# 4,5,6
# 7,8,9
#
#
# Kết quả sau khi skip rows:
#    a  b  c
# 0  1  2  3
# 1  4  5  6
# 2  7  8  9

# %%
import os
import pandas as pd

# Đảm bảo thư mục examples tồn tại
os.makedirs("examples", exist_ok=True)

# Tạo file ex5.csv với một số ô trống
with open("examples/ex5.csv", "w") as f:
    f.write("something,a,b,c,d,message\n")
    f.write("one,1,2,3,4,hello\n")
    f.write("two,5,,7,8,world\n")   # cột b bị thiếu
    f.write("three,9,10,,12,foo\n") # cột c bị thiếu
    f.write("four,13,14,15,16,bar\n")

# Đọc lại bằng pandas
result = pd.read_csv("examples/ex5.csv")
print(result)
# Out:
#   something   a     b     c   d message
# 0       one   1   2.0   3.0   4   hello
# 1       two   5   NaN   7.0   8   world
# 2     three   9  10.0   NaN  12     foo
# 3      four  13  14.0  15.0  16     bar

# %%
pd.isna(result)
# Out:
#    something      a      b      c      d  message
# 0      False  False  False  False  False    False
# 1      False  False   True  False  False    False
# 2      False  False  False   True  False    False
# 3      False  False  False  False  False    False

# %%
result = pd.read_csv("examples/ex5.csv", na_values=["NULL"])
result
# Out:
#   something   a     b     c   d message
# 0       one   1   2.0   3.0   4   hello
# 1       two   5   NaN   7.0   8   world
# 2     three   9  10.0   NaN  12     foo
# 3      four  13  14.0  15.0  16     bar

# %%
result2 = pd.read_csv("examples/ex5.csv", keep_default_na=False)
result2
result2.isna()
result3 = pd.read_csv("examples/ex5.csv", keep_default_na=False,
                      na_values=["NA"])
result3
result3.isna()
# Out:
#    something      a      b      c      d  message
# 0      False  False  False  False  False    False
# 1      False  False  False  False  False    False
# 2      False  False  False  False  False    False
# 3      False  False  False  False  False    False

# %%
sentinels = {"message": ["foo", "NA"], "something": ["two"]}
pd.read_csv("examples/ex5.csv", na_values=sentinels,
            keep_default_na=False)
# Out:
#   something   a   b   c   d message
# 0       one   1   2   3   4   hello
# 1       NaN   5       7   8   world
# 2     three   9  10      12     NaN
# 3      four  13  14  15  16     bar

# %% [markdown]
# ## Reading Text Files in Pieces

# %%
pd.options.display.max_rows = 10

# %%
import pandas as pd
import numpy as np
import os

os.makedirs("examples", exist_ok=True)

N = 10000
df_ex6 = pd.DataFrame({
    "key": np.random.choice(["one", "two", "three", "four"], size=N),
    "value": np.random.randn(N)
})
df_ex6.to_csv("examples/ex6.csv", index=False)

# Đọc lại theo chunksize
chunker = pd.read_csv("examples/ex6.csv", chunksize=1000)

tot = pd.Series([], dtype='int64')
for piece in chunker:
    tot = tot.add(piece["key"].value_counts(), fill_value=0)

tot = tot.sort_values(ascending=False)
print(tot)
# Out:
# key
# three    2546.0
# one      2516.0
# four     2491.0
# two      2447.0
# dtype: float64

# %%
result = pd.read_csv("examples/ex6.csv")
result
# Out:
#         key     value
# 0      four -0.689742
# 1       one  1.026822
# 2       two -0.716712
# 3       two -2.148913
# 4      four  0.813538
# ...     ...       ...
# 9995  three -0.642404
# 9996    one -0.165047
# 9997   four  0.391632
# 9998    two  0.077972
# 9999   four -1.552645
#
# [10000 rows x 2 columns]

# %%
pd.read_csv("examples/ex6.csv", nrows=5)
# Out:
#     key     value
# 0  four -0.689742
# 1   one  1.026822
# 2   two -0.716712
# 3   two -2.148913
# 4  four  0.813538

# %%
chunker = pd.read_csv("examples/ex6.csv", chunksize=1000)
type(chunker)
# Out:
# pandas.io.parsers.readers.TextFileReader

# %%
chunker = pd.read_csv("examples/ex6.csv", chunksize=1000)

tot = pd.Series([], dtype='int64')
for piece in chunker:
    tot = tot.add(piece["key"].value_counts(), fill_value=0)

tot = tot.sort_values(ascending=False)

# %%
tot[:10]
# Out:
# key
# three    2546.0
# one      2516.0
# four     2491.0
# two      2447.0
# dtype: float64

# %% [markdown]
# ## Writing Data to Text Format

# %%
data = pd.read_csv("examples/ex5.csv")
data
# Out:
#   something   a     b     c   d message
# 0       one   1   2.0   3.0   4   hello
# 1       two   5   NaN   7.0   8   world
# 2     three   9  10.0   NaN  12     foo
# 3      four  13  14.0  15.0  16     bar

# %%
data.to_csv("examples/out.csv")
# !cat examples/out.csv
# Out:
# ,something,a,b,c,d,message
# 0,one,1,2.0,3.0,4,hello
# 1,two,5,,7.0,8,world
# 2,three,9,10.0,,12,foo
# 3,four,13,14.0,15.0,16,bar

# %%
import sys
data.to_csv(sys.stdout, sep="|")
# Out:
# |something|a|b|c|d|message
# 0|one|1|2.0|3.0|4|hello
# 1|two|5||7.0|8|world
# 2|three|9|10.0||12|foo
# 3|four|13|14.0|15.0|16|bar

# %%
data.to_csv(sys.stdout, na_rep="NULL")
# Out:
# ,something,a,b,c,d,message
# 0,one,1,2.0,3.0,4,hello
# 1,two,5,NULL,7.0,8,world
# 2,three,9,10.0,NULL,12,foo
# 3,four,13,14.0,15.0,16,bar

# %%
data.to_csv(sys.stdout, index=False, header=False)
# Out:
# one,1,2.0,3.0,4,hello
# two,5,,7.0,8,world
# three,9,10.0,,12,foo
# four,13,14.0,15.0,16,bar

# %%
data.to_csv(sys.stdout, index=False, columns=["a", "b", "c"])
# Out:
# a,b,c
# 1,2.0,3.0
# 5,,7.0
# 9,10.0,
# 13,14.0,15.0

# %% [markdown]
# ## Working with Other Delimited Formats

# %%
import os

# Đảm bảo thư mục examples tồn tại
os.makedirs("examples", exist_ok=True)

# Tạo ex7.csv với tab separator
with open("examples/ex7.csv", "w") as f:
    f.write("a\tb\tc\n")
    f.write("1\t2\t3\n")
    f.write("4\t5\t6\n")
    f.write("7\t8\t9\n")

# %%
import csv
f = open("examples/ex7.csv")
reader = csv.reader(f)

# %%
for line in reader:
    print(line)
f.close()
# Out:
# ['a\tb\tc']
# ['1\t2\t3']
# ['4\t5\t6']
# ['7\t8\t9']

# %%
with open("examples/ex7.csv") as f:
    lines = list(csv.reader(f))

# %%
header, values = lines[0], lines[1:]

# %%
data_dict = {h: v for h, v in zip(header, zip(*values))}
data_dict
# Out:
# {'a\tb\tc': ('1\t2\t3', '4\t5\t6', '7\t8\t9')}

# %% [markdown]
# ## JSON Data

# %%
obj = """
{"name": "Wes",
 "cities_lived": ["Akron", "Nashville", "New York", "San Francisco"],
 "pet": null,
 "siblings": [{"name": "Scott", "age": 34, "hobbies": ["guitars", "soccer"]},
              {"name": "Katie", "age": 42, "hobbies": ["diving", "art"]}]
}
"""

# %%
import json
result = json.loads(obj)
result
# Out:
# {'name': 'Wes',
#  'cities_lived': ['Akron', 'Nashville', 'New York', 'San Francisco'],
#  'pet': None,
#  'siblings': [{'name': 'Scott', 'age': 34, 'hobbies': ['guitars', 'soccer']},
#   {'name': 'Katie', 'age': 42, 'hobbies': ['diving', 'art']}]}

# %%
asjson = json.dumps(result)
asjson
# Out:
# '{"name": "Wes", "cities_lived": ["Akron", "Nashville", "New York", "San Francisco"], "pet": null, "siblings": [{"name": "Scott", "age": 34, "hobbies": ["guitars", "soccer"]}, {"name": "Katie", "age": 42, "hobbies": ["diving", "art"]}]}'

# %%
siblings = pd.DataFrame(result["siblings"], columns=["name", "age"])
siblings
# Out:
#     name  age
# 0  Scott   34
# 1  Katie   42

# %%
import os
import json

# Đảm bảo thư mục examples tồn tại
os.makedirs("examples", exist_ok=True)

data = [
    {"a": 1, "b": 2, "c": 3},
    {"a": 4, "b": 5, "c": 6},
    {"a": 7, "b": 8, "c": 9}
]

# Lưu thành file JSON
with open("examples/example.json", "w") as f:
    json.dump(data, f)

# %%
data = pd.read_json("examples/example.json")
data
# Out:
#    a  b  c
# 0  1  2  3
# 1  4  5  6
# 2  7  8  9

# %%
data.to_json(sys.stdout)
data.to_json(sys.stdout, orient="records")
# Out:
# {"a":{"0":1,"1":4,"2":7},"b":{"0":2,"1":5,"2":8},"c":{"0":3,"1":6,"2":9}}[{"a":1,"b":2,"c":3},{"a":4,"b":5,"c":6},{"a":7,"b":8,"c":9}]

# %% [markdown]
# ## XML and HTML: Web Scraping

# %%
import os, pandas as pd

# 1) Tạo thư mục và file HTML có <table>
os.makedirs("examples", exist_ok=True)
html = """<!doctype html>
<html><head><meta charset="utf-8"><title>FDIC Failed Banks</title></head>
<body>
<table id="failed-banks">
  <thead>
    <tr>
      <th>Bank Name</th><th>City</th><th>ST</th><th>CERT</th>
      <th>Acquiring Institution</th><th>Closing Date</th><th>Fund</th>
    </tr>
  </thead>
  <tbody>
    <tr><td>ABC Bank</td><td>Miami</td><td>FL</td><td>12345</td><td>XYZ Bank</td><td>2025-01-15</td><td>FED</td></tr>
    <tr><td>Demo Bank</td><td>Dallas</td><td>TX</td><td>23456</td><td>Acquirer Co</td><td>2025-02-20</td><td>FDIC</td></tr>
    <tr><td>Sample Bank</td><td>Portland</td><td>OR</td><td>34567</td><td>Alpha NA</td><td>2025-03-30</td><td>FDIC</td></tr>
  </tbody>
</table>
</body></html>"""
with open("examples/fdic_failed_bank_list.html", "w", encoding="utf-8") as f:
    f.write(html)

# 2) Đọc tất cả bảng trong file (trả về list DataFrame)
tables = pd.read_html("examples/fdic_failed_bank_list.html")
print(len(tables))       # số bảng tìm được
failures = tables[0]     # bảng đầu tiên
print(failures.head())
# Out:
# 1
#      Bank Name      City  ST   CERT Acquiring Institution Closing Date  Fund
# 0     ABC Bank     Miami  FL  12345              XYZ Bank   2025-01-15   FED
# 1    Demo Bank    Dallas  TX  23456           Acquirer Co   2025-02-20  FDIC
# 2  Sample Bank  Portland  OR  34567              Alpha NA   2025-03-30  FDIC

# %%
close_timestamps = pd.to_datetime(failures["Closing Date"])
close_timestamps.dt.year.value_counts()
# Out:
# Closing Date
# 2025    3
# Name: count, dtype: int64

# %% [markdown]
# ## Parsing XML with lxml.objectify

# %%
import os
from lxml import objectify
import pandas as pd

def make_mta_xml(path="datasets/mta_perf/Performance_MNR.xml"):
    # Đảm bảo thư mục tồn tại
    os.makedirs(os.path.dirname(path), exist_ok=True)

    # Dữ liệu mẫu
    rows = [
        {"Name": "Hudson",    "OnTime": 95.2, "Ridership": 120000},
        {"Name": "Harlem",    "OnTime": 93.5, "Ridership":  98000},
        {"Name": "New Haven", "OnTime": 91.8, "Ridership": 134000},
    ]

    # Tạo nội dung XML
    xml_content = """<?xml version="1.0"?>\n<Performance>\n"""
    for r in rows:
        xml_content += f"""  <Line>
    <Name>{r['Name']}</Name>
    <OnTime>{r['OnTime']}</OnTime>
    <Ridership>{r['Ridership']}</Ridership>
  </Line>\n"""
    xml_content += "</Performance>"

    # Ghi file
    with open(path, "w", encoding="utf-8") as f:
        f.write(xml_content)

    # Đọc lại
    parsed = objectify.parse(open(path, "rb"))
    root = parsed.getroot()

    # Chuyển sang DataFrame
    data = []
    for line in root.Line:
        data.append({
            "Name": str(line.Name),
            "OnTime": float(line.OnTime),
            "Ridership": int(line.Ridership)
        })
    df = pd.DataFrame(data)

    return df, path, root

# Gọi hàm
df_mta, xml_path, xml_root = make_mta_xml()
print("File đã tạo:", xml_path)
print(df_mta)
# Out:
# File đã tạo: datasets/mta_perf/Performance_MNR.xml
#         Name  OnTime  Ridership
# 0     Hudson    95.2     120000
# 1     Harlem    93.5      98000
# 2  New Haven    91.8     134000

# %%
from lxml import objectify

parsed = objectify.parse(open("datasets/mta_perf/Performance_MNR.xml"))
root = parsed.getroot()

# %%
perf = pd.DataFrame(data)
perf.head()
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
perf2 = pd.read_xml(path)
perf2.head()
# Out:
#         Name  OnTime  Ridership
# 0     Hudson    95.2     120000
# 1     Harlem    93.5      98000
# 2  New Haven    91.8     134000

# %% [markdown]
# ## Binary Data Formats

# %%
frame = pd.read_csv("examples/ex1.csv")
frame
frame.to_pickle("examples/frame_pickle")

# %%
pd.read_pickle("examples/frame_pickle")
# Out:
#    a    b      c
# 0  1  foo   True
# 1  2  bar  False
# 2  3  baz   True
# 3  4  qux  False

# %%
import os
import pandas as pd

# Đảm bảo thư mục tồn tại
os.makedirs("datasets/fec", exist_ok=True)

# Tạo DataFrame giả giống kiểu dữ liệu FEC
df_fake = pd.DataFrame({
    "cand_nm": ["Obama, Barack", "McCain, John", "Obama, Barack", "Clinton, Hillary"],
    "contbr_nm": ["Alice Smith", "Bob Jones", "Charlie White", "Diana Green"],
    "contbr_city": ["New York", "Los Angeles", "Chicago", "Boston"],
    "contbr_st": ["NY", "CA", "IL", "MA"],
    "contbr_employer": ["Self-Employed", "Google", "IBM", "Harvard"],
    "contbr_occupation": ["Attorney", "Engineer", "Manager", "Professor"],
    "contb_receipt_amt": [250, 100, 300, 200]
})

# Lưu thành file parquet
df_fake.to_parquet("datasets/fec/fec.parquet", index=False)

# Đọc lại
fec = pd.read_parquet("datasets/fec/fec.parquet")
print(fec.head())
# Out:
#             cand_nm      contbr_nm  contbr_city contbr_st contbr_employer  \
# 0     Obama, Barack    Alice Smith     New York        NY   Self-Employed
# 1      McCain, John      Bob Jones  Los Angeles        CA          Google
# 2     Obama, Barack  Charlie White      Chicago        IL             IBM
# 3  Clinton, Hillary    Diana Green       Boston        MA         Harvard
#
#   contbr_occupation  contb_receipt_amt
# 0          Attorney                250
# 1          Engineer                100
# 2           Manager                300
# 3         Professor                200

# %% [markdown]
# ## Reading Microsoft Excel Files

# %%
import os
import pandas as pd

# Đảm bảo thư mục tồn tại
os.makedirs("examples", exist_ok=True)

# Tạo DataFrame giả
df_excel = pd.DataFrame({
    "A": [1, 2, 3, 4],
    "B": ["foo", "bar", "baz", "qux"],
    "C": [10.5, 20.1, 30.2, 40.7]
})

# Lưu ra file Excel
df_excel.to_excel("examples/ex1.xlsx", sheet_name="Sheet1", index=False)

# Đọc lại bằng ExcelFile
xlsx = pd.ExcelFile("examples/ex1.xlsx")
print("Các sheet:", xlsx.sheet_names)

# Đọc dữ liệu từ sheet1
df_read = pd.read_excel(xlsx, "Sheet1")
print(df_read)
# Out:
# Các sheet: ['Sheet1']
#    A    B     C
# 0  1  foo  10.5
# 1  2  bar  20.1
# 2  3  baz  30.2
# 3  4  qux  40.7

# %%
writer = pd.ExcelWriter("examples/ex2.xlsx")
frame.to_excel(writer, "Sheet1")
writer.close()
# Out:
# /tmp/ipython-input-4135277578.py:2: FutureWarning: Starting with pandas version 3.0 all arguments of to_excel except for the argument 'excel_writer' will be keyword-only.
#   frame.to_excel(writer, "Sheet1")

# %%
frame.to_excel("examples/ex2.xlsx")

# %% [markdown]
# ## Using HDF5 Format

# %%
frame = pd.DataFrame({"a": np.random.standard_normal(100)})
store = pd.HDFStore("examples/mydata.h5")
store["obj1"] = frame
store["obj1_col"] = frame["a"]
store
# Out:
# <class 'pandas.io.pytables.HDFStore'>
# File path: examples/mydata.h5

# %%
store["obj1"]
# Out:
#            a
# 0   0.660317
# 1  -0.156974
# 2   0.074053
# 3   1.933884
# 4   0.771934
# ..       ...
# 95  0.501741
# 96  1.589523
# 97 -1.213414
# 98  0.385216
# 99  0.482516
#
# [100 rows x 1 columns]

# %%
store.put("obj2", frame, format="table")
store.select("obj2", where=["index >= 10 and index <= 15"])
store.close()

# %%
frame.to_hdf("examples/mydata.h5", "obj3", format="table")
pd.read_hdf("examples/mydata.h5", "obj3", where=["index < 5"])
# Out:
# /tmp/ipython-input-2659235977.py:1: FutureWarning: Starting with pandas version 3.0 all arguments of to_hdf except for the argument 'path_or_buf' will be keyword-only.
#   frame.to_hdf("examples/mydata.h5", "obj3", format="table")
#           a
# 0  0.660317
# 1 -0.156974
# 2  0.074053
# 3  1.933884
# 4  0.771934

# %%
import os
os.remove("examples/mydata.h5")

# %% [markdown]
# ## Interacting with Web APIs

# %%
import requests
url = "https://api.github.com/repos/pandas-dev/pandas/issues"
resp = requests.get(url)
resp.raise_for_status()
resp
# Out:
# <Response [200]>

# %%
data = resp.json()
data[0]["title"]
# Out:
# 'DOC: Clarify parentheses vs. brackets usage (GH#62314)'

# %%
issues = pd.DataFrame(data, columns=["number", "title",
                                     "labels", "state"])
issues
# Out:
#     number                                              title  \
# 0    62347  DOC: Clarify parentheses vs. brackets usage (G...
# 1    62346   DOC: Add missing periods in DataFrame docstrings
# 2    62345  BIG: adding row to DataFrame with EADtype inde...
# 3    62344  BUG: cast_pointwise_result with BooleanDtype a...
# 4    62343  BUG: _get_common_dtype with date32[pyarrow] an...
# ..     ...                                                ...
# 25   62303             BUG: Failed to build Pandas 2.1.x Docs
# 26   62297  BUG: always warn when on_bad_lines callable re...
# 27   62291  TST : Add comprehensive unit tests for tm.shar...
# 28   62290  BUG: Fix incorrect FutureWarning for logical o...
# 29   62287  ENH: Support `method` and `tolerance` kwargs i...
#
#                                                labels state
# 0                                                  []  open
# 1                                                  []  open
# ...

# %% [markdown]
# ## Interacting with Databases

# %%
import sqlite3

query = """
CREATE TABLE test
(a VARCHAR(20), b VARCHAR(20),
 c REAL,        d INTEGER
);"""

con = sqlite3.connect("mydata.sqlite")
con.execute(query)
con.commit()

# %%
data = [("Atlanta", "Georgia", 1.25, 6),
        ("Tallahassee", "Florida", 2.6, 3),
        ("Sacramento", "California", 1.7, 5)]
stmt = "INSERT INTO test VALUES(?, ?, ?, ?)"

con.executemany(stmt, data)
con.commit()

# %%
cursor = con.execute("SELECT * FROM test")
rows = cursor.fetchall()
rows
# Out:
# [('Atlanta', 'Georgia', 1.25, 6),
#  ('Tallahassee', 'Florida', 2.6, 3),
#  ('Sacramento', 'California', 1.7, 5)]

# %%
cursor.description
pd.DataFrame(rows, columns=[x[0] for x in cursor.description])
# Out:
#              a           b     c  d
# 0      Atlanta     Georgia  1.25  6
# 1  Tallahassee     Florida  2.60  3
# 2   Sacramento  California  1.70  5

# %%
import sqlalchemy as sqla
db = sqla.create_engine("sqlite:///mydata.sqlite")
pd.read_sql("SELECT * FROM test", db)
# Out:
#              a           b     c  d
# 0      Atlanta     Georgia  1.25  6
# 1  Tallahassee     Florida  2.60  3
# 2   Sacramento  California  1.70  5

# %%
# !rm mydata.sqlite
